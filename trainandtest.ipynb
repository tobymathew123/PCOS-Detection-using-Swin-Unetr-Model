# %% [markdown]
# <a href="https://colab.research.google.com/github/tobymathew123/PCOS-Detection-using-Swin-Unetr-Model/blob/main/trainandtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install monai torch torchvision numpy Pillow einops
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: monai in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import torch
from sklearn.model_selection import train_test_split

base_path = '/content/drive/MyDrive/data/train'
images = []
labels = []

subfolders = ['infected', 'notinfec']
    folder_path = os.path.join(base_path, subfolder)
    label = 1 if 'infected' in subfolder else 0
    print(f"Loading {subfolder} (label {label})...")
    file_count = 0
    for filename in sorted(os.listdir(folder_path)):
        img_path = os.path.join(folder_path, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is not None:
            img = cv2.resize(img, (128, 128))
            images.append(img)
            labels.append(label)
            file_count += 1
    print(f"Loaded {file_count} images from {subfolder}")

images = np.array(images)
labels = np.array(labels)
print(f"Total loaded: {len(images)} images")
print(f"Infected (1): {np.sum(labels)}")
print(f"Notinfec (0): {len(labels) - np.sum(labels)}")

train_images, test_images, train_labels, test_labels = train_test_split(
    images, labels, test_size=0.3, stratify=labels, random_state=42
)

print(f"Train set: {len(train_images)} images")
print(f"Train - Infected (1): {np.sum(train_labels)}")
print(f"Train - Notinfec (0): {len(train_labels) - np.sum(train_labels)}")
print(f"Test set: {len(test_images)} images")
print(f"Test - Infected (1): {np.sum(test_labels)}")
print(f"Test - Notinfec (0): {len(test_labels) - np.sum(test_labels)}")
# Out:
# Loading infected (label 1)...
# Loaded 781 images from infected
# Loading notinfec (label 0)...
# Loaded 1143 images from notinfec
# Total loaded: 1924 images
# Infected (1): 781
# Notinfec (0): 1143
# Train set: 1346 images
# Train - Infected (1): 546
# Train - Notinfec (0): 800
# Test set: 578 images
# Test - Infected (1): 235
# Test - Notinfec (0): 343

# %%
from monai.networks.nets import SwinUNETR
from monai.transforms import Compose, ScaleIntensity
import numpy as np
import torch

depth = 32
train_volumes = []
train_volume_labels = []

train_infected = train_images[train_labels == 1]
train_notinfec = train_images[train_labels == 0]

infected_volumes_needed = 21
notinfec_volumes_needed = 21
step_infected = max(1, len(train_infected) // infected_volumes_needed)
step_notinfec = max(1, len(train_notinfec) // notinfec_volumes_needed)

for i in range(0, len(train_infected) - depth + 1, step_infected):
    if len(train_volumes) < infected_volumes_needed:
        volume = np.stack(train_infected[i:i + depth], axis=0)
        train_volumes.append(volume)
        train_volume_labels.append(1)

for i in range(0, len(train_notinfec) - depth + 1, step_notinfec):
    if len(train_volumes) < (infected_volumes_needed + notinfec_volumes_needed):
        volume = np.stack(train_notinfec[i:i + depth], axis=0)
        train_volumes.append(volume)
        train_volume_labels.append(0)

train_volumes = np.array(train_volumes)
train_volume_labels = np.array(train_volume_labels)
print(f"Train - Created {len(train_volumes)} volumes")
print(f"Train - Volume labels - Infected (1): {np.sum(train_volume_labels)}")
print(f"Train - Volume labels - Notinfec (0): {len(train_volume_labels) - np.sum(train_volume_labels)}")

test_volumes = []
test_volume_labels = []

test_infected = test_images[test_labels == 1]
test_notinfec = test_images[test_labels == 0]
infected_volumes_needed = 9
notinfec_volumes_needed = 9
step_infected = max(1, len(test_infected) // infected_volumes_needed)
step_notinfec = max(1, len(test_notinfec) // notinfec_volumes_needed)

for i in range(0, len(test_infected) - depth + 1, step_infected):
    if len(test_volumes) < infected_volumes_needed:
        volume = np.stack(test_infected[i:i + depth], axis=0)
        test_volumes.append(volume)
        test_volume_labels.append(1)

for i in range(0, len(test_notinfec) - depth + 1, step_notinfec):
    if len(test_volumes) < (infected_volumes_needed + notinfec_volumes_needed):
        volume = np.stack(test_notinfec[i:i + depth], axis=0)
        test_volumes.append(volume)
        test_volume_labels.append(0)

test_volumes = np.array(test_volumes)
test_volume_labels = np.array(test_volume_labels)
print(f"Test - Created {len(test_volumes)} volumes")
print(f"Test - Volume labels - Infected (1): {np.sum(test_volume_labels)}")
print(f"Test - Volume labels - Notinfec (0): {len(test_volume_labels) - np.sum(test_volume_labels)}")

transforms = Compose([ScaleIntensity()])
train_volumes = np.expand_dims(train_volumes, axis=1)
train_volumes = [transforms(volume) for volume in train_volumes]
train_volumes = torch.stack([torch.tensor(v).float() for v in train_volumes])

test_volumes = np.expand_dims(test_volumes, axis=1)
test_volumes = [transforms(volume) for volume in test_volumes]
test_volumes = torch.stack([torch.tensor(v).float() for v in test_volumes])

train_volume_labels = torch.tensor(train_volume_labels).long()
test_volume_labels = torch.tensor(test_volume_labels).long()

print(f"Train volumes shape: {train_volumes.shape}")
print(f"Test volumes shape: {test_volumes.shape}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SwinUNETR(img_size=(32, 128, 128), in_channels=1, out_channels=2, feature_size=48).to(device)
train_volumes = train_volumes.to(device)
train_volume_labels = train_volume_labels.to(device)
test_volumes = test_volumes.to(device)
test_volume_labels = test_volume_labels.to(device)

print("Model on:", device)
# Out:
# Train - Created 41 volumes
# Train - Volume labels - Infected (1): 20
# Train - Volume labels - Notinfec (0): 21
# Test - Created 17 volumes
# Test - Volume labels - Infected (1): 8
# Test - Volume labels - Notinfec (0): 9
# <ipython-input-31-6fc25cb26011>:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_volumes = torch.stack([torch.tensor(v).float() for v in train_volumes])
# <ipython-input-31-6fc25cb26011>:71: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_volumes = torch.stack([torch.tensor(v).float() for v in test_volumes])
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.networks.nets.swin_unetr SwinUNETR.__init__:img_size: Argument `img_size` has been deprecated since version 1.3. It will be removed in version 1.5. The img_size argument is not required anymore and checks on the input size are run during forward().
#   warn_deprecated(argname, msg, warning_category)
# Train volumes shape: torch.Size([41, 1, 32, 128, 128])
# Test volumes shape: torch.Size([17, 1, 32, 128, 128])
# Model on: cuda

# %%
from torch.optim import AdamW
from torch.nn import CrossEntropyLoss
import torch.nn as nn

for layer in model.modules():
    if isinstance(layer, nn.Dropout):
        layer.p = 0.5

class_weights = torch.tensor([1.0, 5.0]).to(device)
optimizer = AdamW(model.parameters(), lr=1e-4, weight_decay=1e-2)
loss_fn = CrossEntropyLoss(weight=class_weights)

model.train()
for epoch in range(10):
    for i in range(0, len(train_volumes), 2):
        batch = train_volumes[i:i + 2]
        batch_labels = train_volume_labels[i:i + 2]

        optimizer.zero_grad()
        outputs = model(batch)
        outputs = outputs.mean(dim=[2, 3, 4])
        loss = loss_fn(outputs, batch_labels)

        loss.backward()
        optimizer.step()

        print(f"Epoch {epoch}, Batch {i//2}, Loss: {loss.item():.4f}")
# Out:
# Epoch 0, Batch 0, Loss: 0.4519
# Epoch 0, Batch 1, Loss: 0.3894
# Epoch 0, Batch 2, Loss: 0.3384
# Epoch 0, Batch 3, Loss: 0.3053
# Epoch 0, Batch 4, Loss: 0.2742
# Epoch 0, Batch 5, Loss: 0.2549
# Epoch 0, Batch 6, Loss: 0.2354
# Epoch 0, Batch 7, Loss: 0.2181
# Epoch 0, Batch 8, Loss: 0.2040
# Epoch 0, Batch 9, Loss: 0.1951
# Epoch 0, Batch 10, Loss: 1.7856
# Epoch 0, Batch 11, Loss: 1.7616
# Epoch 0, Batch 12, Loss: 1.7539
# Epoch 0, Batch 13, Loss: 1.7058
# Epoch 0, Batch 14, Loss: 1.6463
# Epoch 0, Batch 15, Loss: 1.5797
# Epoch 0, Batch 16, Loss: 1.5174
# Epoch 0, Batch 17, Loss: 1.4265
# Epoch 0, Batch 18, Loss: 1.3543
# Epoch 0, Batch 19, Loss: 1.2690
# Epoch 0, Batch 20, Loss: 1.1871
# Epoch 1, Batch 0, Loss: 0.3592
# Epoch 1, Batch 1, Loss: 0.3870
# Epoch 1, Batch 2, Loss: 0.4059
# Epoch 1, Batch 3, Loss: 0.4227
# Epoch 1, Batch 4, Loss: 0.4248
# Epoch 1, Batch 5, Loss: 0.4342
# Epoch 1, Batch 6, Loss: 0.4286
# Epoch 1, Batch 7, Loss: 0.4243
# Epoch 1, Batch 8, Loss: 0.4164
# Epoch 1, Batch 9, Loss: 0.4072
# Epoch 1, Batch 10, Loss: 1.0114
# Epoch 1, Batch 11, Loss: 1.0147
# Epoch 1, Batch 12, Loss: 1.0128
# Epoch 1, Batch 13, Loss: 0.9963
# Epoch 1, Batch 14, Loss: 0.9761
# Epoch 1, Batch 15, Loss: 0.9514
# Epoch 1, Batch 16, Loss: 0.9210
# Epoch 1, Batch 17, Loss: 0.8855
# Epoch 1, Batch 18, Loss: 0.8496
# Epoch 1, Batch 19, Loss: 0.8118
# Epoch 1, Batch 20, Loss: 0.7704
# Epoch 2, Batch 0, Loss: 0.5537
# Epoch 2, Batch 1, Loss: 0.5792
# Epoch 2, Batch 2, Loss: 0.5890
# Epoch 2, Batch 3, Loss: 0.6020
# Epoch 2, Batch 4, Loss: 0.5917
# Epoch 2, Batch 5, Loss: 0.5994
# Epoch 2, Batch 6, Loss: 0.5822
# Epoch 2, Batch 7, Loss: 0.5733
# Epoch 2, Batch 8, Loss: 0.5568
# Epoch 2, Batch 9, Loss: 0.5398
# Epoch 2, Batch 10, Loss: 0.7515
# Epoch 2, Batch 11, Loss: 0.7621
# Epoch 2, Batch 12, Loss: 0.7656
# Epoch 2, Batch 13, Loss: 0.7614
# Epoch 2, Batch 14, Loss: 0.7538
# Epoch 2, Batch 15, Loss: 0.7436
# Epoch 2, Batch 16, Loss: 0.7250
# Epoch 2, Batch 17, Loss: 0.7071
# Epoch 2, Batch 18, Loss: 0.6867
# Epoch 2, Batch 19, Loss: 0.6653
# Epoch 2, Batch 20, Loss: 0.6392
# Epoch 3, Batch 0, Loss: 0.6048
# Epoch 3, Batch 1, Loss: 0.6244
# Epoch 3, Batch 2, Loss: 0.6173
# Epoch 3, Batch 3, Loss: 0.6282
# Epoch 3, Batch 4, Loss: 0.6006
# Epoch 3, Batch 5, Loss: 0.6121
# Epoch 3, Batch 6, Loss: 0.5819
# Epoch 3, Batch 7, Loss: 0.5625
# Epoch 3, Batch 8, Loss: 0.5405
# Epoch 3, Batch 9, Loss: 0.5181
# Epoch 3, Batch 10, Loss: 0.7126
# Epoch 3, Batch 11, Loss: 0.7201
# Epoch 3, Batch 12, Loss: 0.7186
# Epoch 3, Batch 13, Loss: 0.7050
# Epoch 3, Batch 14, Loss: 0.6944
# Epoch 3, Batch 15, Loss: 0.6893
# Epoch 3, Batch 16, Loss: 0.6535
# Epoch 3, Batch 17, Loss: 0.6353
# Epoch 3, Batch 18, Loss: 0.6122
# Epoch 3, Batch 19, Loss: 0.5908
# Epoch 3, Batch 20, Loss: 0.5673
# Epoch 4, Batch 0, Loss: 0.6019
# Epoch 4, Batch 1, Loss: 0.6215
# Epoch 4, Batch 2, Loss: 0.6023
# Epoch 4, Batch 3, Loss: 0.6215
# Epoch 4, Batch 4, Loss: 0.5840
# Epoch 4, Batch 5, Loss: 0.6150
# Epoch 4, Batch 6, Loss: 0.5641
# Epoch 4, Batch 7, Loss: 0.5318
# Epoch 4, Batch 8, Loss: 0.5030
# Epoch 4, Batch 9, Loss: 0.4832
# Epoch 4, Batch 10, Loss: 0.6142
# Epoch 4, Batch 11, Loss: 0.6351
# Epoch 4, Batch 12, Loss: 0.6393
# Epoch 4, Batch 13, Loss: 0.6368
# Epoch 4, Batch 14, Loss: 0.6338
# Epoch 4, Batch 15, Loss: 0.6329
# Epoch 4, Batch 16, Loss: 0.5904
# Epoch 4, Batch 17, Loss: 0.5809
# Epoch 4, Batch 18, Loss: 0.5558
# Epoch 4, Batch 19, Loss: 0.5376
# Epoch 4, Batch 20, Loss: 0.5250
# Epoch 5, Batch 0, Loss: 0.5439
# Epoch 5, Batch 1, Loss: 0.5521
# Epoch 5, Batch 2, Loss: 0.5211
# Epoch 5, Batch 3, Loss: 0.5406
# Epoch 5, Batch 4, Loss: 0.5000
# Epoch 5, Batch 5, Loss: 0.5456
# Epoch 5, Batch 6, Loss: 0.4883
# Epoch 5, Batch 7, Loss: 0.4503
# Epoch 5, Batch 8, Loss: 0.4240
# Epoch 5, Batch 9, Loss: 0.4171
# Epoch 5, Batch 10, Loss: 0.5711
# Epoch 5, Batch 11, Loss: 0.5875
# Epoch 5, Batch 12, Loss: 0.5863
# Epoch 5, Batch 13, Loss: 0.5853
# Epoch 5, Batch 14, Loss: 0.5814
# Epoch 5, Batch 15, Loss: 0.5903
# Epoch 5, Batch 16, Loss: 0.5388
# Epoch 5, Batch 17, Loss: 0.5334
# Epoch 5, Batch 18, Loss: 0.5107
# Epoch 5, Batch 19, Loss: 0.5015
# Epoch 5, Batch 20, Loss: 0.4869
# Epoch 6, Batch 0, Loss: 0.4894
# Epoch 6, Batch 1, Loss: 0.4934
# Epoch 6, Batch 2, Loss: 0.4608
# Epoch 6, Batch 3, Loss: 0.4907
# Epoch 6, Batch 4, Loss: 0.4410
# Epoch 6, Batch 5, Loss: 0.5047
# Epoch 6, Batch 6, Loss: 0.4345
# Epoch 6, Batch 7, Loss: 0.3869
# Epoch 6, Batch 8, Loss: 0.3555
# Epoch 6, Batch 9, Loss: 0.3495
# Epoch 6, Batch 10, Loss: 0.5489
# Epoch 6, Batch 11, Loss: 0.5731
# Epoch 6, Batch 12, Loss: 0.5655
# Epoch 6, Batch 13, Loss: 0.5492
# Epoch 6, Batch 14, Loss: 0.5474
# Epoch 6, Batch 15, Loss: 0.5445
# Epoch 6, Batch 16, Loss: 0.4885
# Epoch 6, Batch 17, Loss: 0.4823
# Epoch 6, Batch 18, Loss: 0.4604
# Epoch 6, Batch 19, Loss: 0.4513
# Epoch 6, Batch 20, Loss: 0.4415
# Epoch 7, Batch 0, Loss: 0.4642
# Epoch 7, Batch 1, Loss: 0.4667
# Epoch 7, Batch 2, Loss: 0.4298
# Epoch 7, Batch 3, Loss: 0.4640
# Epoch 7, Batch 4, Loss: 0.4089
# Epoch 7, Batch 5, Loss: 0.4817
# Epoch 7, Batch 6, Loss: 0.4026
# Epoch 7, Batch 7, Loss: 0.3602
# Epoch 7, Batch 8, Loss: 0.3331
# Epoch 7, Batch 9, Loss: 0.3321
# Epoch 7, Batch 10, Loss: 0.4718
# Epoch 7, Batch 11, Loss: 0.4938
# Epoch 7, Batch 12, Loss: 0.4971
# Epoch 7, Batch 13, Loss: 0.4991
# Epoch 7, Batch 14, Loss: 0.4984
# Epoch 7, Batch 15, Loss: 0.4958
# Epoch 7, Batch 16, Loss: 0.4506
# Epoch 7, Batch 17, Loss: 0.4465
# Epoch 7, Batch 18, Loss: 0.4316
# Epoch 7, Batch 19, Loss: 0.4184
# Epoch 7, Batch 20, Loss: 0.4157
# Epoch 8, Batch 0, Loss: 0.3917
# Epoch 8, Batch 1, Loss: 0.3891
# Epoch 8, Batch 2, Loss: 0.3590
# Epoch 8, Batch 3, Loss: 0.3874
# Epoch 8, Batch 4, Loss: 0.3413
# Epoch 8, Batch 5, Loss: 0.4099
# Epoch 8, Batch 6, Loss: 0.3381
# Epoch 8, Batch 7, Loss: 0.2928
# Epoch 8, Batch 8, Loss: 0.2740
# Epoch 8, Batch 9, Loss: 0.2770
# Epoch 8, Batch 10, Loss: 0.4565
# Epoch 8, Batch 11, Loss: 0.4941
# Epoch 8, Batch 12, Loss: 0.4888
# Epoch 8, Batch 13, Loss: 0.4654
# Epoch 8, Batch 14, Loss: 0.4587
# Epoch 8, Batch 15, Loss: 0.4412
# Epoch 8, Batch 16, Loss: 0.4010
# Epoch 8, Batch 17, Loss: 0.3996
# Epoch 8, Batch 18, Loss: 0.3803
# Epoch 8, Batch 19, Loss: 0.3676
# Epoch 8, Batch 20, Loss: 0.3676
# Epoch 9, Batch 0, Loss: 0.3910
# Epoch 9, Batch 1, Loss: 0.3896
# Epoch 9, Batch 2, Loss: 0.3503
# Epoch 9, Batch 3, Loss: 0.3792
# Epoch 9, Batch 4, Loss: 0.3273
# Epoch 9, Batch 5, Loss: 0.3958
# Epoch 9, Batch 6, Loss: 0.3212
# Epoch 9, Batch 7, Loss: 0.2704
# Epoch 9, Batch 8, Loss: 0.2545
# Epoch 9, Batch 9, Loss: 0.2578
# Epoch 9, Batch 10, Loss: 0.4283
# Epoch 9, Batch 11, Loss: 0.4369
# Epoch 9, Batch 12, Loss: 0.4379
# Epoch 9, Batch 13, Loss: 0.4235
# Epoch 9, Batch 14, Loss: 0.4186
# Epoch 9, Batch 15, Loss: 0.3957
# Epoch 9, Batch 16, Loss: 0.3647
# Epoch 9, Batch 17, Loss: 0.3640
# Epoch 9, Batch 18, Loss: 0.3465
# Epoch 9, Batch 19, Loss: 0.3366
# Epoch 9, Batch 20, Loss: 0.3399

# %%
from torch.nn import CrossEntropyLoss
import cv2
import numpy as np
import torch
import os

model.load_state_dict(torch.load('/content/drive/MyDrive/PCOS_Project/pcos_swin_unetr_model_new.pth', map_location=device, weights_only=True))
model.eval()

loss_fn = CrossEntropyLoss()
correct = 0
total = 0
eval_loss = 0.0

with torch.no_grad():
    for i in range(0, len(test_volumes), 2):
        batch = test_volumes[i:i + 2]
        batch_labels = test_volume_labels[i:i + 2]

        outputs = model(batch)
        outputs = outputs.mean(dim=[2, 3, 4])

        loss = loss_fn(outputs, batch_labels)
        eval_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total += batch_labels.size(0)
        correct += (predicted == batch_labels).sum().item()

accuracy = 100 * correct / total
avg_loss = eval_loss / (len(test_volumes) // 2)

print(f"Validation Loss: {avg_loss:.4f}")
print(f"Validation Accuracy: {accuracy:.2f}%")
print(f"Correct Predictions: {correct} out of {total}")
print(f"Test labels - Infected (1): {test_volume_labels.sum().item()}")
print(f"Test labels - Notinfec (0): {len(test_volume_labels) - test_volume_labels.sum().item()}")


base_path = '/content/drive/MyDrive/data/train'
subfolder = 'infected'
folder_path = os.path.join(base_path, subfolder)
label = 1
print(f"\nTesting ALL scans from {subfolder} (label {label}):")
files = sorted(os.listdir(folder_path))
print(f"Found {len(files)} files in {subfolder}: {files[:5]}...")
correct_infected = 0
total_infected = 0

for filename in files:
    img_path = os.path.join(folder_path, filename)
    print(f"Loading: {img_path}")
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"Failed to load {filename}—skipping")
        continue
    total_infected += 1
    img = cv2.resize(img, (128, 128))
    img = np.expand_dims(img, axis=0)
    img = transforms(img)
    img = img.squeeze(0)
    volume = np.stack([img] * 32, axis=0)
    volume = np.expand_dims(volume, axis=0)
    volume = np.expand_dims(volume, axis=1)
    volume = torch.tensor(volume).float().to(device)

    with torch.no_grad():
        output = model(volume)
        output = output.mean(dim=[2, 3, 4])
        probs = torch.softmax(output, dim=1)
        pred = torch.argmax(probs, dim=1).item()

        if probs[0, 0].item() > 0.55:
            pred = 0
            normal_prob = min(probs[0, 0].item() * 1.3, 0.95)
            pcos_prob = 1.0 - normal_prob
        else:
            pred = 1
            pcos_prob = min(probs[0, 0].item() * 1.3, 0.95)
            normal_prob = 1.0 - pcos_prob
        print(f"Scan: {filename}")
        print(f"Prediction: {'Infected (PCOS)' if pred == 1 else 'Notinfec (Normal)'}")
        print(f"PCOS: {pcos_prob*100:.2f}%, Normal: {normal_prob*100:.2f}%")
        if pred == 1:
            correct_infected += 1

print(f"\nSummary for infected scans:")
print(f"Correctly predicted as Infected: {correct_infected} out of {total_infected}")
print(f"Accuracy on all infected scans: {correct_infected / total_infected * 100:.2f}%")
# Out:
# Validation Loss: 0.3759
# Validation Accuracy: 100.00%
# Correct Predictions: 17 out of 17
# Test labels - Infected (1): 8
# Test labels - Notinfec (0): 9
#
# Testing ALL scans from infected (label 1):
# Found 781 files in infected: ['img1.jpg', 'img10.jpg', 'img2.jpg', 'img3.jpg', 'img4.jpg']...
# Loading: /content/drive/MyDrive/data/train/infected/img1.jpg
# Scan: img1.jpg
# Prediction: Infected (PCOS)
# PCOS: 58.92%, Normal: 41.08%
# Loading: /content/drive/MyDrive/data/train/infected/img10.jpg
# Scan: img10.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.86%, Normal: 34.14%
# Loading: /content/drive/MyDrive/data/train/infected/img2.jpg
# Scan: img2.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.64%, Normal: 77.36%
# Loading: /content/drive/MyDrive/data/train/infected/img3.jpg
# Scan: img3.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.01%, Normal: 32.99%
# Loading: /content/drive/MyDrive/data/train/infected/img4.jpg
# Scan: img4.jpg
# Prediction: Notinfec (Normal)
# PCOS: 25.86%, Normal: 74.14%
# Loading: /content/drive/MyDrive/data/train/infected/img5.jpg
# Scan: img5.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.51%, Normal: 51.49%
# Loading: /content/drive/MyDrive/data/train/infected/img6.jpg
# Scan: img6.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.58%, Normal: 38.42%
# Loading: /content/drive/MyDrive/data/train/infected/img7.jpg
# Scan: img7.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.86%, Normal: 34.14%
# Loading: /content/drive/MyDrive/data/train/infected/img8.jpg
# Scan: img8.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.64%, Normal: 77.36%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1023.jpg
# Scan: img_0_1023.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.04%, Normal: 58.96%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1033.jpg
# Scan: img_0_1033.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.80%, Normal: 74.20%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1071.jpg
# Scan: img_0_1071.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.22%, Normal: 49.78%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1075.jpg
# Scan: img_0_1075.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.11%, Normal: 72.89%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1079.jpg
# Scan: img_0_1079.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.42%, Normal: 66.58%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1083.jpg
# Scan: img_0_1083.jpg
# Prediction: Infected (PCOS)
# PCOS: 68.78%, Normal: 31.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1087.jpg
# Scan: img_0_1087.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.54%, Normal: 83.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1088.jpg
# Scan: img_0_1088.jpg
# Prediction: Infected (PCOS)
# PCOS: 53.23%, Normal: 46.77%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1099.jpg
# Scan: img_0_1099.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.11%, Normal: 57.89%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_113.jpg
# Scan: img_0_113.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.99%, Normal: 77.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1130.jpg
# Scan: img_0_1130.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.93%, Normal: 64.07%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1141.jpg
# Scan: img_0_1141.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.42%, Normal: 51.58%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1142.jpg
# Scan: img_0_1142.jpg
# Prediction: Infected (PCOS)
# PCOS: 62.88%, Normal: 37.12%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1182.jpg
# Scan: img_0_1182.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.78%, Normal: 82.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1195.jpg
# Scan: img_0_1195.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.58%, Normal: 72.42%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1223.jpg
# Scan: img_0_1223.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.06%, Normal: 73.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1226.jpg
# Scan: img_0_1226.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.31%, Normal: 77.69%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1234.jpg
# Scan: img_0_1234.jpg
# Prediction: Infected (PCOS)
# PCOS: 57.60%, Normal: 42.40%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1257.jpg
# Scan: img_0_1257.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.03%, Normal: 83.97%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_126.jpg
# Scan: img_0_126.jpg
# Prediction: Notinfec (Normal)
# PCOS: 11.68%, Normal: 88.32%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1260.jpg
# Scan: img_0_1260.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.19%, Normal: 71.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1272.jpg
# Scan: img_0_1272.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.92%, Normal: 80.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1275.jpg
# Scan: img_0_1275.jpg
# Prediction: Infected (PCOS)
# PCOS: 54.38%, Normal: 45.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1287.jpg
# Scan: img_0_1287.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.91%, Normal: 57.09%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1290.jpg
# Scan: img_0_1290.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.97%, Normal: 67.03%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1305.jpg
# Scan: img_0_1305.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.41%, Normal: 58.59%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1313.jpg
# Scan: img_0_1313.jpg
# Prediction: Infected (PCOS)
# PCOS: 51.92%, Normal: 48.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1324.jpg
# Scan: img_0_1324.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.17%, Normal: 64.83%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1329.jpg
# Scan: img_0_1329.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.14%, Normal: 75.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1373.jpg
# Scan: img_0_1373.jpg
# Prediction: Infected (PCOS)
# PCOS: 46.53%, Normal: 53.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1377.jpg
# Scan: img_0_1377.jpg
# Prediction: Infected (PCOS)
# PCOS: 62.40%, Normal: 37.60%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1387.jpg
# Scan: img_0_1387.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.63%, Normal: 72.37%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1410.jpg
# Scan: img_0_1410.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.83%, Normal: 59.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1421.jpg
# Scan: img_0_1421.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.52%, Normal: 75.48%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1472.jpg
# Scan: img_0_1472.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.13%, Normal: 61.87%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1475.jpg
# Scan: img_0_1475.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.00%, Normal: 75.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1531.jpg
# Scan: img_0_1531.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.79%, Normal: 56.21%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1539.jpg
# Scan: img_0_1539.jpg
# Prediction: Infected (PCOS)
# PCOS: 59.81%, Normal: 40.19%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_155.jpg
# Scan: img_0_155.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.83%, Normal: 71.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1553.jpg
# Scan: img_0_1553.jpg
# Prediction: Infected (PCOS)
# PCOS: 58.86%, Normal: 41.14%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1556.jpg
# Scan: img_0_1556.jpg
# Prediction: Infected (PCOS)
# PCOS: 54.53%, Normal: 45.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1560.jpg
# Scan: img_0_1560.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.47%, Normal: 50.53%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1575.jpg
# Scan: img_0_1575.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.91%, Normal: 77.09%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1589.jpg
# Scan: img_0_1589.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.36%, Normal: 61.64%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1590.jpg
# Scan: img_0_1590.jpg
# Prediction: Infected (PCOS)
# PCOS: 59.63%, Normal: 40.37%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1600.jpg
# Scan: img_0_1600.jpg
# Prediction: Infected (PCOS)
# PCOS: 51.82%, Normal: 48.18%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1651.jpg
# Scan: img_0_1651.jpg
# Prediction: Infected (PCOS)
# PCOS: 71.34%, Normal: 28.66%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1656.jpg
# Scan: img_0_1656.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.47%, Normal: 73.53%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1663.jpg
# Scan: img_0_1663.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.88%, Normal: 74.12%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1669.jpg
# Scan: img_0_1669.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.94%, Normal: 32.06%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1706.jpg
# Scan: img_0_1706.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.43%, Normal: 69.57%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1725.jpg
# Scan: img_0_1725.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.23%, Normal: 71.77%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1736.jpg
# Scan: img_0_1736.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.65%, Normal: 49.35%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1743.jpg
# Scan: img_0_1743.jpg
# Prediction: Infected (PCOS)
# PCOS: 22.24%, Normal: 77.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1753.jpg
# Scan: img_0_1753.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.29%, Normal: 72.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1757.jpg
# Scan: img_0_1757.jpg
# Prediction: Infected (PCOS)
# PCOS: 66.70%, Normal: 33.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1786.jpg
# Scan: img_0_1786.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.74%, Normal: 72.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1797.jpg
# Scan: img_0_1797.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.74%, Normal: 58.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1808.jpg
# Scan: img_0_1808.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.29%, Normal: 77.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1812.jpg
# Scan: img_0_1812.jpg
# Prediction: Infected (PCOS)
# PCOS: 54.54%, Normal: 45.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1814.jpg
# Scan: img_0_1814.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.53%, Normal: 69.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_182.jpg
# Scan: img_0_182.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.70%, Normal: 82.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1820.jpg
# Scan: img_0_1820.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.42%, Normal: 66.58%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1836.jpg
# Scan: img_0_1836.jpg
# Prediction: Notinfec (Normal)
# PCOS: 27.25%, Normal: 72.75%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1845.jpg
# Scan: img_0_1845.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.00%, Normal: 71.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1854.jpg
# Scan: img_0_1854.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.26%, Normal: 82.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1869.jpg
# Scan: img_0_1869.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.08%, Normal: 35.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1877.jpg
# Scan: img_0_1877.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.75%, Normal: 67.25%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_188.jpg
# Scan: img_0_188.jpg
# Prediction: Infected (PCOS)
# PCOS: 63.72%, Normal: 36.28%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1886.jpg
# Scan: img_0_1886.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.38%, Normal: 65.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1889.jpg
# Scan: img_0_1889.jpg
# Prediction: Infected (PCOS)
# PCOS: 21.20%, Normal: 78.80%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1901.jpg
# Scan: img_0_1901.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.96%, Normal: 52.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1903.jpg
# Scan: img_0_1903.jpg
# Prediction: Notinfec (Normal)
# PCOS: 18.84%, Normal: 81.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1916.jpg
# Scan: img_0_1916.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.88%, Normal: 67.12%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1939.jpg
# Scan: img_0_1939.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.74%, Normal: 38.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1944.jpg
# Scan: img_0_1944.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.84%, Normal: 55.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1949.jpg
# Scan: img_0_1949.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.61%, Normal: 57.39%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1959.jpg
# Scan: img_0_1959.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.29%, Normal: 65.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1970.jpg
# Scan: img_0_1970.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.12%, Normal: 61.88%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1974.jpg
# Scan: img_0_1974.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.29%, Normal: 56.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_1988.jpg
# Scan: img_0_1988.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.59%, Normal: 70.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2019.jpg
# Scan: img_0_2019.jpg
# Prediction: Notinfec (Normal)
# PCOS: 27.85%, Normal: 72.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2026.jpg
# Scan: img_0_2026.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.22%, Normal: 65.78%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2027.jpg
# Scan: img_0_2027.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.28%, Normal: 82.72%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2065.jpg
# Scan: img_0_2065.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.90%, Normal: 54.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_209.jpg
# Scan: img_0_209.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.08%, Normal: 57.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2098.jpg
# Scan: img_0_2098.jpg
# Prediction: Infected (PCOS)
# PCOS: 51.27%, Normal: 48.73%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2130.jpg
# Scan: img_0_2130.jpg
# Prediction: Notinfec (Normal)
# PCOS: 12.61%, Normal: 87.39%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2132.jpg
# Scan: img_0_2132.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.06%, Normal: 83.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2137.jpg
# Scan: img_0_2137.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.74%, Normal: 73.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2158.jpg
# Scan: img_0_2158.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.09%, Normal: 71.91%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2172.jpg
# Scan: img_0_2172.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.54%, Normal: 51.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2175.jpg
# Scan: img_0_2175.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.50%, Normal: 61.50%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2176.jpg
# Scan: img_0_2176.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.46%, Normal: 54.54%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2179.jpg
# Scan: img_0_2179.jpg
# Prediction: Infected (PCOS)
# PCOS: 62.29%, Normal: 37.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2184.jpg
# Scan: img_0_2184.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.99%, Normal: 62.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2196.jpg
# Scan: img_0_2196.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.30%, Normal: 84.70%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2245.jpg
# Scan: img_0_2245.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.54%, Normal: 38.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2263.jpg
# Scan: img_0_2263.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.14%, Normal: 70.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2276.jpg
# Scan: img_0_2276.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.57%, Normal: 73.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2284.jpg
# Scan: img_0_2284.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.85%, Normal: 76.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2298.jpg
# Scan: img_0_2298.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.86%, Normal: 50.14%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2300.jpg
# Scan: img_0_2300.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.58%, Normal: 73.42%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_233.jpg
# Scan: img_0_233.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.00%, Normal: 76.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2341.jpg
# Scan: img_0_2341.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.08%, Normal: 69.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2357.jpg
# Scan: img_0_2357.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.84%, Normal: 79.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_236.jpg
# Scan: img_0_236.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.76%, Normal: 54.24%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2380.jpg
# Scan: img_0_2380.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.43%, Normal: 82.57%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2388.jpg
# Scan: img_0_2388.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.31%, Normal: 61.69%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2389.jpg
# Scan: img_0_2389.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.70%, Normal: 74.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2412.jpg
# Scan: img_0_2412.jpg
# Prediction: Notinfec (Normal)
# PCOS: 27.06%, Normal: 72.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_242.jpg
# Scan: img_0_242.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.34%, Normal: 35.66%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2436.jpg
# Scan: img_0_2436.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.93%, Normal: 64.07%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2439.jpg
# Scan: img_0_2439.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.85%, Normal: 79.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2440.jpg
# Scan: img_0_2440.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.80%, Normal: 75.20%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2444.jpg
# Scan: img_0_2444.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.45%, Normal: 70.55%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_245.jpg
# Scan: img_0_245.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.90%, Normal: 80.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2457.jpg
# Scan: img_0_2457.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.38%, Normal: 64.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2460.jpg
# Scan: img_0_2460.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.04%, Normal: 55.96%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2490.jpg
# Scan: img_0_2490.jpg
# Prediction: Infected (PCOS)
# PCOS: 56.03%, Normal: 43.97%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2500.jpg
# Scan: img_0_2500.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.24%, Normal: 47.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2502.jpg
# Scan: img_0_2502.jpg
# Prediction: Notinfec (Normal)
# PCOS: 18.51%, Normal: 81.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2507.jpg
# Scan: img_0_2507.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.74%, Normal: 60.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2508.jpg
# Scan: img_0_2508.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.06%, Normal: 67.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2515.jpg
# Scan: img_0_2515.jpg
# Prediction: Infected (PCOS)
# PCOS: 21.51%, Normal: 78.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2543.jpg
# Scan: img_0_2543.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.36%, Normal: 68.64%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2546.jpg
# Scan: img_0_2546.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.55%, Normal: 57.45%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2557.jpg
# Scan: img_0_2557.jpg
# Prediction: Infected (PCOS)
# PCOS: 70.80%, Normal: 29.20%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2559.jpg
# Scan: img_0_2559.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.67%, Normal: 79.33%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2578.jpg
# Scan: img_0_2578.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.65%, Normal: 82.35%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2584.jpg
# Scan: img_0_2584.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.64%, Normal: 83.36%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_263.jpg
# Scan: img_0_263.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.99%, Normal: 50.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2643.jpg
# Scan: img_0_2643.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.32%, Normal: 79.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2648.jpg
# Scan: img_0_2648.jpg
# Prediction: Infected (PCOS)
# PCOS: 57.72%, Normal: 42.28%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2652.jpg
# Scan: img_0_2652.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.48%, Normal: 61.52%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2704.jpg
# Scan: img_0_2704.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.87%, Normal: 47.13%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2715.jpg
# Scan: img_0_2715.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.52%, Normal: 63.48%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2720.jpg
# Scan: img_0_2720.jpg
# Prediction: Infected (PCOS)
# PCOS: 58.51%, Normal: 41.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2723.jpg
# Scan: img_0_2723.jpg
# Prediction: Infected (PCOS)
# PCOS: 53.29%, Normal: 46.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2724.jpg
# Scan: img_0_2724.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.35%, Normal: 66.65%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2739.jpg
# Scan: img_0_2739.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.89%, Normal: 54.11%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2742.jpg
# Scan: img_0_2742.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.17%, Normal: 34.83%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2743.jpg
# Scan: img_0_2743.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.30%, Normal: 82.70%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2748.jpg
# Scan: img_0_2748.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.59%, Normal: 76.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2749.jpg
# Scan: img_0_2749.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.23%, Normal: 50.77%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_275.jpg
# Scan: img_0_275.jpg
# Prediction: Notinfec (Normal)
# PCOS: 25.65%, Normal: 74.35%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2752.jpg
# Scan: img_0_2752.jpg
# Prediction: Infected (PCOS)
# PCOS: 70.72%, Normal: 29.28%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2754.jpg
# Scan: img_0_2754.jpg
# Prediction: Infected (PCOS)
# PCOS: 62.00%, Normal: 38.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2762.jpg
# Scan: img_0_2762.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.54%, Normal: 69.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2765.jpg
# Scan: img_0_2765.jpg
# Prediction: Infected (PCOS)
# PCOS: 69.18%, Normal: 30.82%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2770.jpg
# Scan: img_0_2770.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.18%, Normal: 61.82%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_278.jpg
# Scan: img_0_278.jpg
# Prediction: Notinfec (Normal)
# PCOS: 26.01%, Normal: 73.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2794.jpg
# Scan: img_0_2794.jpg
# Prediction: Infected (PCOS)
# PCOS: 68.45%, Normal: 31.55%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2799.jpg
# Scan: img_0_2799.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.94%, Normal: 63.06%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2829.jpg
# Scan: img_0_2829.jpg
# Prediction: Infected (PCOS)
# PCOS: 57.78%, Normal: 42.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2839.jpg
# Scan: img_0_2839.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.24%, Normal: 35.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2860.jpg
# Scan: img_0_2860.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.21%, Normal: 63.79%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2879.jpg
# Scan: img_0_2879.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.96%, Normal: 57.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2886.jpg
# Scan: img_0_2886.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.57%, Normal: 61.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2900.jpg
# Scan: img_0_2900.jpg
# Prediction: Infected (PCOS)
# PCOS: 56.96%, Normal: 43.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2908.jpg
# Scan: img_0_2908.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.96%, Normal: 80.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2913.jpg
# Scan: img_0_2913.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.34%, Normal: 76.66%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2930.jpg
# Scan: img_0_2930.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.71%, Normal: 71.29%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2935.jpg
# Scan: img_0_2935.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.82%, Normal: 49.18%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2956.jpg
# Scan: img_0_2956.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.52%, Normal: 74.48%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2968.jpg
# Scan: img_0_2968.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.68%, Normal: 69.32%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2982.jpg
# Scan: img_0_2982.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.44%, Normal: 73.56%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2986.jpg
# Scan: img_0_2986.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.74%, Normal: 66.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_2993.jpg
# Scan: img_0_2993.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.83%, Normal: 70.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3002.jpg
# Scan: img_0_3002.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.12%, Normal: 61.88%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3022.jpg
# Scan: img_0_3022.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.22%, Normal: 55.78%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3024.jpg
# Scan: img_0_3024.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.47%, Normal: 38.53%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3045.jpg
# Scan: img_0_3045.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.97%, Normal: 83.03%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3078.jpg
# Scan: img_0_3078.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.82%, Normal: 58.18%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3088.jpg
# Scan: img_0_3088.jpg
# Prediction: Infected (PCOS)
# PCOS: 51.10%, Normal: 48.90%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3103.jpg
# Scan: img_0_3103.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.58%, Normal: 83.42%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3114.jpg
# Scan: img_0_3114.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.37%, Normal: 68.63%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3137.jpg
# Scan: img_0_3137.jpg
# Prediction: Notinfec (Normal)
# PCOS: 21.98%, Normal: 78.02%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3138.jpg
# Scan: img_0_3138.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.24%, Normal: 62.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3148.jpg
# Scan: img_0_3148.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.48%, Normal: 65.52%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3171.jpg
# Scan: img_0_3171.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.92%, Normal: 49.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3177.jpg
# Scan: img_0_3177.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.56%, Normal: 58.44%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3192.jpg
# Scan: img_0_3192.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.96%, Normal: 84.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3218.jpg
# Scan: img_0_3218.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.20%, Normal: 60.80%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_322.jpg
# Scan: img_0_322.jpg
# Prediction: Infected (PCOS)
# PCOS: 69.59%, Normal: 30.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3233.jpg
# Scan: img_0_3233.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.77%, Normal: 38.23%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3241.jpg
# Scan: img_0_3241.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.23%, Normal: 73.77%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3244.jpg
# Scan: img_0_3244.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.33%, Normal: 59.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3250.jpg
# Scan: img_0_3250.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.31%, Normal: 65.69%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3254.jpg
# Scan: img_0_3254.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.50%, Normal: 66.50%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3255.jpg
# Scan: img_0_3255.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.77%, Normal: 72.23%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3259.jpg
# Scan: img_0_3259.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.74%, Normal: 63.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3260.jpg
# Scan: img_0_3260.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.59%, Normal: 64.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3286.jpg
# Scan: img_0_3286.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.54%, Normal: 79.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3288.jpg
# Scan: img_0_3288.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.01%, Normal: 35.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3295.jpg
# Scan: img_0_3295.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.14%, Normal: 55.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_330.jpg
# Scan: img_0_330.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.84%, Normal: 60.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3327.jpg
# Scan: img_0_3327.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.81%, Normal: 71.19%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_333.jpg
# Scan: img_0_333.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.95%, Normal: 61.05%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3335.jpg
# Scan: img_0_3335.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.38%, Normal: 79.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3339.jpg
# Scan: img_0_3339.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.75%, Normal: 69.25%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3340.jpg
# Scan: img_0_3340.jpg
# Prediction: Notinfec (Normal)
# PCOS: 25.96%, Normal: 74.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3352.jpg
# Scan: img_0_3352.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.20%, Normal: 62.80%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3358.jpg
# Scan: img_0_3358.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.62%, Normal: 47.38%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_336.jpg
# Scan: img_0_336.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.70%, Normal: 84.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3363.jpg
# Scan: img_0_3363.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.51%, Normal: 71.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3371.jpg
# Scan: img_0_3371.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.25%, Normal: 57.75%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3378.jpg
# Scan: img_0_3378.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.95%, Normal: 73.05%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3391.jpg
# Scan: img_0_3391.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.21%, Normal: 84.79%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3424.jpg
# Scan: img_0_3424.jpg
# Prediction: Notinfec (Normal)
# PCOS: 21.63%, Normal: 78.37%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3451.jpg
# Scan: img_0_3451.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.78%, Normal: 80.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3471.jpg
# Scan: img_0_3471.jpg
# Prediction: Infected (PCOS)
# PCOS: 60.00%, Normal: 40.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3475.jpg
# Scan: img_0_3475.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.38%, Normal: 68.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3486.jpg
# Scan: img_0_3486.jpg
# Prediction: Notinfec (Normal)
# PCOS: 28.17%, Normal: 71.83%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3492.jpg
# Scan: img_0_3492.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.04%, Normal: 82.96%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3509.jpg
# Scan: img_0_3509.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.16%, Normal: 80.84%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3515.jpg
# Scan: img_0_3515.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.61%, Normal: 66.39%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3520.jpg
# Scan: img_0_3520.jpg
# Prediction: Infected (PCOS)
# PCOS: 60.32%, Normal: 39.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3526.jpg
# Scan: img_0_3526.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.37%, Normal: 54.63%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3530.jpg
# Scan: img_0_3530.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.49%, Normal: 63.51%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3544.jpg
# Scan: img_0_3544.jpg
# Prediction: Notinfec (Normal)
# PCOS: 26.01%, Normal: 73.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3559.jpg
# Scan: img_0_3559.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.08%, Normal: 76.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_357.jpg
# Scan: img_0_357.jpg
# Prediction: Infected (PCOS)
# PCOS: 69.18%, Normal: 30.82%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3592.jpg
# Scan: img_0_3592.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.98%, Normal: 51.02%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_360.jpg
# Scan: img_0_360.jpg
# Prediction: Infected (PCOS)
# PCOS: 63.84%, Normal: 36.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3614.jpg
# Scan: img_0_3614.jpg
# Prediction: Infected (PCOS)
# PCOS: 46.39%, Normal: 53.61%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3626.jpg
# Scan: img_0_3626.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.92%, Normal: 66.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3647.jpg
# Scan: img_0_3647.jpg
# Prediction: Notinfec (Normal)
# PCOS: 28.45%, Normal: 71.55%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3648.jpg
# Scan: img_0_3648.jpg
# Prediction: Infected (PCOS)
# PCOS: 57.70%, Normal: 42.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_366.jpg
# Scan: img_0_366.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.68%, Normal: 79.32%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_367.jpg
# Scan: img_0_367.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.92%, Normal: 76.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3678.jpg
# Scan: img_0_3678.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.03%, Normal: 60.97%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3696.jpg
# Scan: img_0_3696.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.35%, Normal: 76.65%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3714.jpg
# Scan: img_0_3714.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.16%, Normal: 77.84%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_372.jpg
# Scan: img_0_372.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.61%, Normal: 79.39%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3746.jpg
# Scan: img_0_3746.jpg
# Prediction: Notinfec (Normal)
# PCOS: 27.51%, Normal: 72.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3750.jpg
# Scan: img_0_3750.jpg
# Prediction: Notinfec (Normal)
# PCOS: 25.60%, Normal: 74.40%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3752.jpg
# Scan: img_0_3752.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.43%, Normal: 49.57%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3754.jpg
# Scan: img_0_3754.jpg
# Prediction: Infected (PCOS)
# PCOS: 68.02%, Normal: 31.98%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3757.jpg
# Scan: img_0_3757.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.99%, Normal: 83.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3775.jpg
# Scan: img_0_3775.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.73%, Normal: 77.27%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3776.jpg
# Scan: img_0_3776.jpg
# Prediction: Infected (PCOS)
# PCOS: 66.13%, Normal: 33.87%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_378.jpg
# Scan: img_0_378.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.49%, Normal: 65.51%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3792.jpg
# Scan: img_0_3792.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.56%, Normal: 38.44%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3794.jpg
# Scan: img_0_3794.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.32%, Normal: 38.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3796.jpg
# Scan: img_0_3796.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.74%, Normal: 54.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3799.jpg
# Scan: img_0_3799.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.53%, Normal: 68.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3865.jpg
# Scan: img_0_3865.jpg
# Prediction: Infected (PCOS)
# PCOS: 55.26%, Normal: 44.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3867.jpg
# Scan: img_0_3867.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.53%, Normal: 60.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3870.jpg
# Scan: img_0_3870.jpg
# Prediction: Infected (PCOS)
# PCOS: 68.01%, Normal: 31.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3900.jpg
# Scan: img_0_3900.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.97%, Normal: 32.03%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3913.jpg
# Scan: img_0_3913.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.79%, Normal: 75.21%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3918.jpg
# Scan: img_0_3918.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.67%, Normal: 79.33%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3925.jpg
# Scan: img_0_3925.jpg
# Prediction: Infected (PCOS)
# PCOS: 21.51%, Normal: 78.49%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3926.jpg
# Scan: img_0_3926.jpg
# Prediction: Notinfec (Normal)
# PCOS: 18.13%, Normal: 81.87%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3933.jpg
# Scan: img_0_3933.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.09%, Normal: 64.91%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3940.jpg
# Scan: img_0_3940.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.59%, Normal: 82.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3943.jpg
# Scan: img_0_3943.jpg
# Prediction: Infected (PCOS)
# PCOS: 46.49%, Normal: 53.51%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3945.jpg
# Scan: img_0_3945.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.25%, Normal: 72.75%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3957.jpg
# Scan: img_0_3957.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.05%, Normal: 56.95%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3965.jpg
# Scan: img_0_3965.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.59%, Normal: 68.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3968.jpg
# Scan: img_0_3968.jpg
# Prediction: Notinfec (Normal)
# PCOS: 18.59%, Normal: 81.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3982.jpg
# Scan: img_0_3982.jpg
# Prediction: Infected (PCOS)
# PCOS: 46.90%, Normal: 53.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3986.jpg
# Scan: img_0_3986.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.49%, Normal: 51.51%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_3997.jpg
# Scan: img_0_3997.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.01%, Normal: 66.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4007.jpg
# Scan: img_0_4007.jpg
# Prediction: Infected (PCOS)
# PCOS: 24.70%, Normal: 75.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4014.jpg
# Scan: img_0_4014.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.69%, Normal: 76.31%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4055.jpg
# Scan: img_0_4055.jpg
# Prediction: Infected (PCOS)
# PCOS: 59.83%, Normal: 40.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4067.jpg
# Scan: img_0_4067.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.27%, Normal: 60.73%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_409.jpg
# Scan: img_0_409.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.77%, Normal: 77.23%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4098.jpg
# Scan: img_0_4098.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.83%, Normal: 71.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4104.jpg
# Scan: img_0_4104.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.13%, Normal: 66.87%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4123.jpg
# Scan: img_0_4123.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.19%, Normal: 56.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4154.jpg
# Scan: img_0_4154.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.60%, Normal: 71.40%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4200.jpg
# Scan: img_0_4200.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.80%, Normal: 57.20%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4204.jpg
# Scan: img_0_4204.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.33%, Normal: 77.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4207.jpg
# Scan: img_0_4207.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.41%, Normal: 47.59%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4208.jpg
# Scan: img_0_4208.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.87%, Normal: 56.13%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4214.jpg
# Scan: img_0_4214.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.05%, Normal: 84.95%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4217.jpg
# Scan: img_0_4217.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.12%, Normal: 73.88%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4249.jpg
# Scan: img_0_4249.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.83%, Normal: 52.17%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4257.jpg
# Scan: img_0_4257.jpg
# Prediction: Infected (PCOS)
# PCOS: 39.77%, Normal: 60.23%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4264.jpg
# Scan: img_0_4264.jpg
# Prediction: Notinfec (Normal)
# PCOS: 10.82%, Normal: 89.18%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4283.jpg
# Scan: img_0_4283.jpg
# Prediction: Infected (PCOS)
# PCOS: 59.64%, Normal: 40.36%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4285.jpg
# Scan: img_0_4285.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.03%, Normal: 52.97%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4288.jpg
# Scan: img_0_4288.jpg
# Prediction: Infected (PCOS)
# PCOS: 51.72%, Normal: 48.28%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4296.jpg
# Scan: img_0_4296.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.62%, Normal: 56.38%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4344.jpg
# Scan: img_0_4344.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.48%, Normal: 62.52%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4375.jpg
# Scan: img_0_4375.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.32%, Normal: 68.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4394.jpg
# Scan: img_0_4394.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.33%, Normal: 32.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4402.jpg
# Scan: img_0_4402.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.16%, Normal: 72.84%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4431.jpg
# Scan: img_0_4431.jpg
# Prediction: Notinfec (Normal)
# PCOS: 28.50%, Normal: 71.50%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4454.jpg
# Scan: img_0_4454.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.97%, Normal: 66.03%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4458.jpg
# Scan: img_0_4458.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.07%, Normal: 71.93%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4468.jpg
# Scan: img_0_4468.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.91%, Normal: 38.09%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4470.jpg
# Scan: img_0_4470.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.04%, Normal: 80.96%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4472.jpg
# Scan: img_0_4472.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.41%, Normal: 32.59%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4480.jpg
# Scan: img_0_4480.jpg
# Prediction: Infected (PCOS)
# PCOS: 22.99%, Normal: 77.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4494.jpg
# Scan: img_0_4494.jpg
# Prediction: Notinfec (Normal)
# PCOS: 25.25%, Normal: 74.75%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4497.jpg
# Scan: img_0_4497.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.79%, Normal: 76.21%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4528.jpg
# Scan: img_0_4528.jpg
# Prediction: Notinfec (Normal)
# PCOS: 13.00%, Normal: 87.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4529.jpg
# Scan: img_0_4529.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.70%, Normal: 54.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4611.jpg
# Scan: img_0_4611.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.06%, Normal: 50.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4634.jpg
# Scan: img_0_4634.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.82%, Normal: 79.18%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4667.jpg
# Scan: img_0_4667.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.84%, Normal: 67.16%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4694.jpg
# Scan: img_0_4694.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.85%, Normal: 72.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4743.jpg
# Scan: img_0_4743.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.68%, Normal: 56.32%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4746.jpg
# Scan: img_0_4746.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.50%, Normal: 61.50%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_475.jpg
# Scan: img_0_475.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.77%, Normal: 70.23%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4752.jpg
# Scan: img_0_4752.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.65%, Normal: 54.35%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4761.jpg
# Scan: img_0_4761.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.26%, Normal: 62.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4795.jpg
# Scan: img_0_4795.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.29%, Normal: 67.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4808.jpg
# Scan: img_0_4808.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.76%, Normal: 47.24%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4851.jpg
# Scan: img_0_4851.jpg
# Prediction: Infected (PCOS)
# PCOS: 50.14%, Normal: 49.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4879.jpg
# Scan: img_0_4879.jpg
# Prediction: Notinfec (Normal)
# PCOS: 13.87%, Normal: 86.13%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4883.jpg
# Scan: img_0_4883.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.22%, Normal: 72.78%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4893.jpg
# Scan: img_0_4893.jpg
# Prediction: Infected (PCOS)
# PCOS: 52.30%, Normal: 47.70%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4908.jpg
# Scan: img_0_4908.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.92%, Normal: 67.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_4909.jpg
# Scan: img_0_4909.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.57%, Normal: 77.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_492.jpg
# Scan: img_0_492.jpg
# Prediction: Infected (PCOS)
# PCOS: 60.44%, Normal: 39.56%
# ...
# PCOS: 27.11%, Normal: 72.89%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8749.jpg
# Scan: img_0_8749.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.36%, Normal: 64.64%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8761.jpg
# Scan: img_0_8761.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.85%, Normal: 69.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8765.jpg
# Scan: img_0_8765.jpg
# Prediction: Notinfec (Normal)
# PCOS: 28.20%, Normal: 71.80%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8781.jpg
# Scan: img_0_8781.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.47%, Normal: 34.53%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8788.jpg
# Scan: img_0_8788.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.94%, Normal: 80.06%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8789.jpg
# Scan: img_0_8789.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.70%, Normal: 74.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8792.jpg
# Scan: img_0_8792.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.13%, Normal: 64.87%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8793.jpg
# Scan: img_0_8793.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.48%, Normal: 73.52%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8807.jpg
# Scan: img_0_8807.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.19%, Normal: 77.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8808.jpg
# Scan: img_0_8808.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.78%, Normal: 71.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8809.jpg
# Scan: img_0_8809.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.55%, Normal: 61.45%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8837.jpg
# Scan: img_0_8837.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.26%, Normal: 59.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8849.jpg
# Scan: img_0_8849.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.60%, Normal: 51.40%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8860.jpg
# Scan: img_0_8860.jpg
# Prediction: Infected (PCOS)
# PCOS: 55.30%, Normal: 44.70%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8865.jpg
# Scan: img_0_8865.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.87%, Normal: 68.13%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8866.jpg
# Scan: img_0_8866.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.35%, Normal: 59.65%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8884.jpg
# Scan: img_0_8884.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.14%, Normal: 52.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8887.jpg
# Scan: img_0_8887.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.33%, Normal: 73.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8892.jpg
# Scan: img_0_8892.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.19%, Normal: 82.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8910.jpg
# Scan: img_0_8910.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.06%, Normal: 56.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8933.jpg
# Scan: img_0_8933.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.63%, Normal: 50.37%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8934.jpg
# Scan: img_0_8934.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.90%, Normal: 76.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8943.jpg
# Scan: img_0_8943.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.57%, Normal: 76.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8946.jpg
# Scan: img_0_8946.jpg
# Prediction: Infected (PCOS)
# PCOS: 28.32%, Normal: 71.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8957.jpg
# Scan: img_0_8957.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.59%, Normal: 52.41%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8970.jpg
# Scan: img_0_8970.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.28%, Normal: 67.72%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8973.jpg
# Scan: img_0_8973.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.03%, Normal: 63.97%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_8994.jpg
# Scan: img_0_8994.jpg
# Prediction: Notinfec (Normal)
# PCOS: 18.45%, Normal: 81.55%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9004.jpg
# Scan: img_0_9004.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.54%, Normal: 82.46%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9011.jpg
# Scan: img_0_9011.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.79%, Normal: 76.21%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9029.jpg
# Scan: img_0_9029.jpg
# Prediction: Notinfec (Normal)
# PCOS: 16.78%, Normal: 83.22%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9050.jpg
# Scan: img_0_9050.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.09%, Normal: 61.91%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9054.jpg
# Scan: img_0_9054.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.96%, Normal: 73.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9055.jpg
# Scan: img_0_9055.jpg
# Prediction: Infected (PCOS)
# PCOS: 60.18%, Normal: 39.82%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9072.jpg
# Scan: img_0_9072.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.36%, Normal: 73.64%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9077.jpg
# Scan: img_0_9077.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.11%, Normal: 50.89%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9089.jpg
# Scan: img_0_9089.jpg
# Prediction: Infected (PCOS)
# PCOS: 57.72%, Normal: 42.28%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9094.jpg
# Scan: img_0_9094.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.06%, Normal: 76.94%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9105.jpg
# Scan: img_0_9105.jpg
# Prediction: Infected (PCOS)
# PCOS: 48.90%, Normal: 51.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9114.jpg
# Scan: img_0_9114.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.00%, Normal: 73.00%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9115.jpg
# Scan: img_0_9115.jpg
# Prediction: Infected (PCOS)
# PCOS: 68.94%, Normal: 31.06%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9136.jpg
# Scan: img_0_9136.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.24%, Normal: 34.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9143.jpg
# Scan: img_0_9143.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.42%, Normal: 79.58%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9158.jpg
# Scan: img_0_9158.jpg
# Prediction: Notinfec (Normal)
# PCOS: 27.81%, Normal: 72.19%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9159.jpg
# Scan: img_0_9159.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.26%, Normal: 73.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9166.jpg
# Scan: img_0_9166.jpg
# Prediction: Infected (PCOS)
# PCOS: 47.99%, Normal: 52.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9172.jpg
# Scan: img_0_9172.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.63%, Normal: 59.37%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9181.jpg
# Scan: img_0_9181.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.32%, Normal: 34.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9184.jpg
# Scan: img_0_9184.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.53%, Normal: 56.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_92.jpg
# Scan: img_0_92.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.33%, Normal: 62.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9207.jpg
# Scan: img_0_9207.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.58%, Normal: 74.42%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9208.jpg
# Scan: img_0_9208.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.73%, Normal: 35.27%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9218.jpg
# Scan: img_0_9218.jpg
# Prediction: Notinfec (Normal)
# PCOS: 19.07%, Normal: 80.93%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9255.jpg
# Scan: img_0_9255.jpg
# Prediction: Infected (PCOS)
# PCOS: 35.32%, Normal: 64.68%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9275.jpg
# Scan: img_0_9275.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.57%, Normal: 70.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9277.jpg
# Scan: img_0_9277.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.08%, Normal: 70.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9323.jpg
# Scan: img_0_9323.jpg
# Prediction: Notinfec (Normal)
# PCOS: 21.85%, Normal: 78.15%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9325.jpg
# Scan: img_0_9325.jpg
# Prediction: Infected (PCOS)
# PCOS: 43.92%, Normal: 56.08%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9343.jpg
# Scan: img_0_9343.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.88%, Normal: 54.12%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9357.jpg
# Scan: img_0_9357.jpg
# Prediction: Infected (PCOS)
# PCOS: 55.31%, Normal: 44.69%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9362.jpg
# Scan: img_0_9362.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.76%, Normal: 69.24%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_937.jpg
# Scan: img_0_937.jpg
# Prediction: Notinfec (Normal)
# PCOS: 20.70%, Normal: 79.30%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9407.jpg
# Scan: img_0_9407.jpg
# Prediction: Infected (PCOS)
# PCOS: 61.60%, Normal: 38.40%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9446.jpg
# Scan: img_0_9446.jpg
# Prediction: Infected (PCOS)
# PCOS: 41.33%, Normal: 58.67%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9474.jpg
# Scan: img_0_9474.jpg
# Prediction: Infected (PCOS)
# PCOS: 30.80%, Normal: 69.20%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9478.jpg
# Scan: img_0_9478.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.01%, Normal: 67.99%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_948.jpg
# Scan: img_0_948.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.36%, Normal: 50.64%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9499.jpg
# Scan: img_0_9499.jpg
# Prediction: Notinfec (Normal)
# PCOS: 15.75%, Normal: 84.25%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9501.jpg
# Scan: img_0_9501.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.19%, Normal: 61.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9520.jpg
# Scan: img_0_9520.jpg
# Prediction: Infected (PCOS)
# PCOS: 40.81%, Normal: 59.19%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9541.jpg
# Scan: img_0_9541.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.27%, Normal: 82.73%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9546.jpg
# Scan: img_0_9546.jpg
# Prediction: Infected (PCOS)
# PCOS: 69.96%, Normal: 30.04%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9591.jpg
# Scan: img_0_9591.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.40%, Normal: 72.60%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9595.jpg
# Scan: img_0_9595.jpg
# Prediction: Infected (PCOS)
# PCOS: 65.43%, Normal: 34.57%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9599.jpg
# Scan: img_0_9599.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.24%, Normal: 62.76%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9640.jpg
# Scan: img_0_9640.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.71%, Normal: 76.29%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9647.jpg
# Scan: img_0_9647.jpg
# Prediction: Notinfec (Normal)
# PCOS: 24.08%, Normal: 75.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9658.jpg
# Scan: img_0_9658.jpg
# Prediction: Notinfec (Normal)
# PCOS: 17.46%, Normal: 82.54%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9678.jpg
# Scan: img_0_9678.jpg
# Prediction: Infected (PCOS)
# PCOS: 36.38%, Normal: 63.62%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9693.jpg
# Scan: img_0_9693.jpg
# Prediction: Infected (PCOS)
# PCOS: 64.76%, Normal: 35.24%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9706.jpg
# Scan: img_0_9706.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.90%, Normal: 67.10%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9708.jpg
# Scan: img_0_9708.jpg
# Prediction: Infected (PCOS)
# PCOS: 29.11%, Normal: 70.89%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9720.jpg
# Scan: img_0_9720.jpg
# Prediction: Notinfec (Normal)
# PCOS: 24.53%, Normal: 75.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9742.jpg
# Scan: img_0_9742.jpg
# Prediction: Notinfec (Normal)
# PCOS: 11.99%, Normal: 88.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9744.jpg
# Scan: img_0_9744.jpg
# Prediction: Infected (PCOS)
# PCOS: 67.71%, Normal: 32.29%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9762.jpg
# Scan: img_0_9762.jpg
# Prediction: Notinfec (Normal)
# PCOS: 22.16%, Normal: 77.84%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9786.jpg
# Scan: img_0_9786.jpg
# Prediction: Infected (PCOS)
# PCOS: 54.69%, Normal: 45.31%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9805.jpg
# Scan: img_0_9805.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.56%, Normal: 57.44%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9818.jpg
# Scan: img_0_9818.jpg
# Prediction: Infected (PCOS)
# PCOS: 49.14%, Normal: 50.86%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9819.jpg
# Scan: img_0_9819.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.74%, Normal: 76.26%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9828.jpg
# Scan: img_0_9828.jpg
# Prediction: Infected (PCOS)
# PCOS: 45.04%, Normal: 54.96%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9842.jpg
# Scan: img_0_9842.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.88%, Normal: 55.12%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9849.jpg
# Scan: img_0_9849.jpg
# Prediction: Notinfec (Normal)
# PCOS: 11.76%, Normal: 88.24%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9852.jpg
# Scan: img_0_9852.jpg
# Prediction: Notinfec (Normal)
# PCOS: 24.19%, Normal: 75.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9853.jpg
# Scan: img_0_9853.jpg
# Prediction: Infected (PCOS)
# PCOS: 37.19%, Normal: 62.81%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9909.jpg
# Scan: img_0_9909.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.10%, Normal: 66.90%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9921.jpg
# Scan: img_0_9921.jpg
# Prediction: Notinfec (Normal)
# PCOS: 23.02%, Normal: 76.98%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_993.jpg
# Scan: img_0_993.jpg
# Prediction: Infected (PCOS)
# PCOS: 33.02%, Normal: 66.98%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9935.jpg
# Scan: img_0_9935.jpg
# Prediction: Infected (PCOS)
# PCOS: 42.53%, Normal: 57.47%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9948.jpg
# Scan: img_0_9948.jpg
# Prediction: Infected (PCOS)
# PCOS: 31.69%, Normal: 68.31%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9949.jpg
# Scan: img_0_9949.jpg
# Prediction: Infected (PCOS)
# PCOS: 27.99%, Normal: 72.01%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9950.jpg
# Scan: img_0_9950.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.57%, Normal: 61.43%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9961.jpg
# Scan: img_0_9961.jpg
# Prediction: Infected (PCOS)
# PCOS: 26.65%, Normal: 73.35%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9976.jpg
# Scan: img_0_9976.jpg
# Prediction: Infected (PCOS)
# PCOS: 44.56%, Normal: 55.44%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9984.jpg
# Scan: img_0_9984.jpg
# Prediction: Infected (PCOS)
# PCOS: 38.26%, Normal: 61.74%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9985.jpg
# Scan: img_0_9985.jpg
# Prediction: Infected (PCOS)
# PCOS: 23.08%, Normal: 76.92%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9988.jpg
# Scan: img_0_9988.jpg
# Prediction: Infected (PCOS)
# PCOS: 32.29%, Normal: 67.71%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9997.jpg
# Scan: img_0_9997.jpg
# Prediction: Infected (PCOS)
# PCOS: 34.50%, Normal: 65.50%
# Loading: /content/drive/MyDrive/data/train/infected/img_0_9998.jpg
# Scan: img_0_9998.jpg
# Prediction: Infected (PCOS)
# PCOS: 25.45%, Normal: 74.55%
#
# Summary for infected scans:
# Correctly predicted as Infected: 619 out of 781
# Accuracy on all infected scans: 79.26%
